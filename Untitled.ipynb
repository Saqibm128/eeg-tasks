# %%
import util_funcs
import data_reader as read
import pyedflib as edf

# %% [markdown]
# # Reviewing data exposed by pyedflib
# ## All fields exposed by edfReader

# %%
testfile = "/home/ms994/v1.5.0/edf/dev_test/01_tcp_ar/002/00000258/s002_2003_07_21/00000258_s002_t000.edf"
exampleReader = edf.EdfReader(testfile, check_file_size=edf.DO_NOT_CHECK_FILE_SIZE)
#All fields exposed by a normal EdfReader, with the library I'm using
# https://www.edfplus.info/specs/edfplus.html#additionalspecs
print(dir(exampleReader))
print('gender: ', exampleReader.gender)
print('birthdate: ', exampleReader.getBirthdate())
exampleReader._close()
# Out:
# ['__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_close', '_convert_string', '_get_float', 'admincode', 'annotations_in_file', 'birthdate', 'check_open_ok', 'datarecord_duration', 'datarecords_in_file', 'digital_max', 'digital_min', 'equipment', 'file_duration', 'file_info', 'file_info_long', 'file_name', 'gender', 'getAdmincode', 'getBirthdate', 'getDigitalMaximum', 'getDigitalMinimum', 'getEquipment', 'getFileDuration', 'getGender', 'getHeader', 'getLabel', 'getNSamples', 'getPatientAdditional', 'getPatientCode', 'getPatientName', 'getPhysicalDimension', 'getPhysicalMaximum', 'getPhysicalMinimum', 'getPrefilter', 'getRecordingAdditional', 'getSampleFrequencies', 'getSampleFrequency', 'getSignalHeader', 'getSignalHeaders', 'getSignalLabels', 'getStartdatetime', 'getTechnician', 'getTransducer', 'handle', 'load_datarecord', 'make_buffer', 'open', 'patient', 'patient_additional', 'patientcode', 'patientname', 'physical_dimension', 'physical_max', 'physical_min', 'prefilter', 'readAnnotations', 'readSignal', 'read_annotation', 'read_digital_signal', 'readsignal', 'recording_additional', 'samplefrequency', 'samples_in_datarecord', 'samples_in_file', 'signal_label', 'signals_in_file', 'startdate_day', 'startdate_month', 'startdate_year', 'starttime_hour', 'starttime_minute', 'starttime_second', 'technician', 'transducer']
# gender:  b''
# birthdate:

# %% [markdown]
# ## Going through all the edf files to see if any data is set

# %%
#Go through all edf files and check and see the unique/distinc machines among all
all_token_fns = read.get_all_token_file_names("train", "01_tcp_ar")
uniqueMachines = set()
for token_fn in all_token_fns:
    with edf.EdfReader(token_fn, check_file_size=edf.DO_NOT_CHECK_FILE_SIZE) as reader:
        uniqueMachines.add(reader.getEquipment())
print(uniqueMachines)
# Out:
# {''}

# %%
#Go through all edf files and check and see the unique/distinc technicians among all
all_token_fns = read.get_all_token_file_names("train", "01_tcp_ar")
uniqueTechs = set()
for token_fn in all_token_fns:
    with edf.EdfReader(token_fn, check_file_size=edf.DO_NOT_CHECK_FILE_SIZE) as reader:
        uniqueTechs.add(reader.getTechnician())
print(uniqueTechs)
# Out:
# {''}

# %% [markdown]
# # Get clinical notes
# ## Getting the ages

# %%
from importlib import reload
reload(read)
import re

# %%
#sample clinical notes
txt = read.get_all_clinical_notes(testfile)
txt
# Out:
# 'CLINICAL HISTORY: This is a 41-year-old male with a history of seizures secondary to astrocytoma with a resection x 2, admitted for increasing seizures.\nMEDICATIONS: Dilantin, Phenobarbital, and Baclofen.\nINTRODUCTION: Digital video EEG is performed at the bedside in the long-term monitoring unit using standard 10-20 system of electrode placement with one channel of EKG.\nDESCRIPTION OF THE RECORD: The background EEG is low voltage.  There is nearly continuous T4 spike wave activity. Soon after the recording begins, at 17:13, the patient has his first seizure.  It starts with his right hand rubbing his nose and staying there for about 10 to 15 seconds.  He then began to shake in his left hand, going up to his shoulder, then involving the right hand and both legs.  At that time, his face is turned to the right. Subsequently, his right hand stops shaking and only his left arm and right leg are still shaking.  At that time, his face turns to the left with both eyes deviated to the left. On the video, the rhythm of the left arm shaking is different from that of the right leg shaking.  It seems that the right leg shakes faster than the left arm for about 10 seconds and then the shaking is synchronized (left arm and right leg).  This spell lasts for about three minutes and the patient stopped seizing without a postictal phase and was moving spontaneously his left arm and could talk.  These types of spells occurred quite frequently, anywhere from several minutes to 30 minutes. During the spell, he can hold some objects in his right hand without dropping them.  After the seizure, the patient can put the objects by the bedside himself.  On the tracing, we counted a total number of spells to be 76. More than 40 occurred prior to midnight and about 30 after midnight.  Some high amplitude spike waves emanating from the C4 leads were seen in about half of the patient’s spells.  All of the patient’s spells had a similar course, lasting about 2 to 3 minutes. They started at the left arm, going to the right arm and then generalized tonic-clonic jerking. There was right shaking first and then asymmetric shaking of the left arm and right leg.  From the video, the patient seems to be unresponsive during his spells, but he responds normally immediately after the spells stop.\nHR:  84 BPM.\nIMPRESSION: Abnormal EEG due to:\n1.  More than 100 seizures\nFrequent epileptiform discharges, which were well correlated with clinical seizures.\nNearly continuous T4 spike waves.\nLow voltage recording.\nCLINICAL CORRELATION: This video EEG demonstrates frequent epileptiform discharges and is well correlated with clinical seizure activity.  The nearly continuous right temporal spike waves may be suggestive of a local pathology for epilepsy.\n\n\n\n\n'

# %%
num_hits = []
ages = {}
for token_fn in all_token_fns:
    clinical_fn = read.convert_edf_path_to_txt(token_fn)
    if clinical_fn in ages:
        continue
    else:
        ages[clinical_fn] = None
    try:
        txt = read.get_all_clinical_notes(token_fn)
        match = re.search(r'(\d+)\s*-\s*year\s*-\s*old', txt)
        if match is None:
            match = re.search(r'(\d+)\s*year\s*old', txt)
            if match is None:
                match = re.search(r'(\d+)\s*y\.\s*o\.', txt)
                if match is None:
                    match = re.match(r'(\d+)\s*(yr|YR)', txt)
                    if match is None:
                        num_hits.append(0)
#                         print(txt)
                        continue
        num_hits.append(len(match.groups()))
        if len(match.groups()) != 0:
            ages[clinical_fn] = (match.group(1))
    except:
        print("Could not read {}".format(token_fn))
# Out:
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/114/00011455/s001_2014_05_09/00011455_s001_t001.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s005_2010_04_19/00006440_s005_t001.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s001_2010_04_17/00006440_s001_t001.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s002_2010_04_17/00006440_s002_t003.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s003_2010_04_18/00006440_s003_t000.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/115/00011562/s001_2014_05_31/00011562_s001_t000.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/115/00011562/s005_2014_06_10/00011562_s005_t000.edf

# %%
reload(read)
ages = read.getAgesAndFileNames("train", "01_tcp_ar")
ages = [ageFn[1] for ageFn in ages]
# Out:
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/114/00011455/s001_2014_05_09/00011455_s001_t001.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s005_2010_04_19/00006440_s005_t001.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s001_2010_04_17/00006440_s001_t001.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s002_2010_04_17/00006440_s002_t003.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/064/00006440/s003_2010_04_18/00006440_s003_t000.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/115/00011562/s001_2014_05_31/00011562_s001_t000.edf
# Could not read /home/ms994/v1.5.0/edf/train/01_tcp_ar/115/00011562/s005_2014_06_10/00011562_s005_t000.edf

# %%
ages
# Out:
# [29,
#  42,
#  42,
#  42,
#  42,
#  50,
#  62,
#  22,
#  61,
#  24,
#  21,
#  21,
#  20,
#  47,
#  47,
#  54,
#  54,
#  63,
#  64,
#  52,
#  52,
#  52,
#  52,
#  60,
#  60,
#  60,
#  60,
#  36,
#  47,
#  23,
#  62,
#  62,
#  62,
#  62,
#  62,
#  77,
#  45,
#  50,
#  82,
#  58,
#  29,
#  51,
#  25,
#  75,
#  19,
#  40,
#  49,
#  49,
#  59,
#  59,
#  59,
#  59,
#  33,
#  33,
#  77,
#  19,
#  59,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  53,
#  52,
#  28,
#  30,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  44,
#  61,
#  61,
#  53,
#  70,
#  70,
#  58,
#  41,
#  41,
#  47,
#  43,
#  58,
#  59,
#  53,
#  28,
#  28,
#  28,
#  31,
#  49,
#  49,
#  49,
#  49,
#  21,
#  21,
#  75,
#  75,
#  75,
#  75,
#  75,
#  29,
#  60,
#  62,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  82,
#  36,
#  36,
#  27,
#  55,
#  55,
#  55,
#  55,
#  55,
#  55,
#  42,
#  47,
#  25,
#  18,
#  54,
#  49,
#  49,
#  49,
#  49,
#  55,
#  55,
#  55,
#  55,
#  65,
#  65,
#  65,
#  65,
#  65,
#  65,
#  65,
#  65,
#  66,
#  65,
#  40,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  38,
#  60,
#  58,
#  58,
#  31,
#  57,
#  66,
#  65,
#  29,
#  32,
#  30,
#  44,
#  44,
#  44,
#  44,
#  58,
#  58,
#  58,
#  58,
#  52,
#  81,
#  81,
#  81,
#  53,
#  44,
#  44,
#  62,
#  47,
#  67,
#  65,
#  64,
#  61,
#  61,
#  41,
#  51,
#  51,
#  51,
#  51,
#  61,
#  29,
#  29,
#  29,
#  50,
#  50,
#  41,
#  55,
#  55,
#  68,
#  42,
#  67,
#  67,
#  66,
#  66,
#  67,
#  67,
#  67,
#  67,
#  21,
#  64,
#  42,
#  44,
#  44,
#  44,
#  43,
#  44,
#  30,
#  23,
#  23,
#  22,
#  22,
#  23,
#  22,
#  22,
#  22,
#  23,
#  23,
#  22,
#  22,
#  60,
#  51,
#  49,
#  70,
#  70,
#  70,
#  47,
#  47,
#  42,
#  42,
#  42,
#  42,
#  39,
#  57,
#  57,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  61,
#  53,
#  87,
#  67,
#  67,
#  67,
#  46,
#  60,
#  77,
#  54,
#  75,
#  72,
#  72,
#  74,
#  69,
#  69,
#  58,
#  50,
#  47,
#  20,
#  43,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  56,
#  36,
#  36,
#  36,
#  49,
#  49,
#  49,
#  49,
#  38,
#  38,
#  22,
#  58,
#  78,
#  31,
#  58,
#  21,
#  48,
#  30,
#  19,
#  61,
#  68,
#  68,
#  68,
#  65,
#  52,
#  51,
#  30,
#  63,
#  62,
#  23,
#  23,
#  70,
#  70,
#  39,
#  53,
#  53,
#  48,
#  41,
#  33,
#  28,
#  27,
#  55,
#  55,
#  55,
#  80,
#  84,
#  60,
#  60,
#  60,
#  46,
#  22,
#  31,
#  33,
#  37,
#  73,
#  73,
#  73,
#  40,
#  33,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  58,
#  58,
#  58,
#  36,
#  43,
#  43,
#  43,
#  24,
#  24,
#  24,
#  24,
#  61,
#  73,
#  61,
#  29,
#  61,
#  54,
#  22,
#  22,
#  22,
#  37,
#  25,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  57,
#  56,
#  56,
#  56,
#  56,
#  52,
#  52,
#  52,
#  52,
#  73,
#  65,
#  46,
#  46,
#  44,
#  45,
#  45,
#  65,
#  63,
#  51,
#  51,
#  40,
#  54,
#  65,
#  65,
#  65,
#  54,
#  72,
#  19,
#  63,
#  42,
#  55,
#  55,
#  46,
#  55,
#  46,
#  55,
#  51,
#  51,
#  69,
#  26,
#  25,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  28,
#  33,
#  33,
#  40,
#  46,
#  46,
#  65,
#  55,
#  68,
#  27,
#  47,
#  80,
#  80,
#  80,
#  39,
#  39,
#  52,
#  73,
#  77,
#  46,
#  19,
#  81,
#  21,
#  30,
#  48,
#  48,
#  23,
#  29,
#  64,
#  64,
#  64,
#  69,
#  69,
#  48,
#  48,
#  48,
#  48,
#  57,
#  68,
#  68,
#  66,
#  66,
#  66,
#  66,
#  48,
#  61,
#  61,
#  61,
#  61,
#  61,
#  81,
#  81,
#  33,
#  33,
#  33,
#  42,
#  57,
#  27,
#  83,
#  23,
#  33,
#  61,
#  71,
#  63,
#  29,
#  29,
#  29,
#  29,
#  29,
#  27,
#  62,
#  24,
#  24,
#  53,
#  53,
#  53,
#  53,
#  23,
#  67,
#  42,
#  34,
#  48,
#  48,
#  48,
#  48,
#  48,
#  47,
#  31,
#  64,
#  64,
#  64,
#  36,
#  37,
#  65,
#  66,
#  66,
#  66,
#  66,
#  66,
#  66,
#  72,
#  39,
#  39,
#  53,
#  33,
#  54,
#  54,
#  54,
#  38,
#  55,
#  55,
#  55,
#  50,
#  50,
#  22,
#  65,
#  19,
#  68,
#  30,
#  52,
#  52,
#  52,
#  52,
#  21,
#  21,
#  21,
#  20,
#  20,
#  20,
#  20,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  88,
#  22,
#  22,
#  58,
#  58,
#  58,
#  22,
#  38,
#  38,
#  23,
#  23,
#  78,
#  43,
#  43,
#  34]

# %%
sum([val is None for val in ages.values()])
# Out:
# 120

# %%
581/len(ages)
# Out:
# 0.8288159771754636

# %%
import matplotlib.pyplot as plt
plt.hist([int(age) for age in ages])
plt.title("Distribution of Ages")
plt.xlabel("Age (years)")
plt.ylabel("Frequency (number of Patients)")
plt.show()

# %% [markdown]
# ## Heart Rate

# %%
num_hits = []
bpm = []
for token_fn in all_token_fns:
    txt = read.get_all_clinical_notes(token_fn)
    txt = txt.lower()
    match = re.search(r'(\d+)\s*b\W*p\W*m', txt)
    if match is None:
        match = re.search(r'(\d+)\s*h\W*r(\W+\s+)', txt)
        if match is None:
            match = re.search(r'heart\s*rate\s*\W*\s*(\d+)', txt)
            if match is None:
                print(txt)
                continue
    num_hits.append(len(match.groups()))
    if len(match.groups()) != 0:
        bpm.append((match.group(1)))
    else:
        bpm.append(-1)
# Out:
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	 depakote, phenobarbital, dilantin
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for 24 hours from 09/03/2015 till 09/04/2015.   nursing-
# initiated event buttons were correlated with clinical behavior.  graphical representation of the eeg
# was available at the bedside and over the hospital network for continuous review by trained nurses
# and eeg technologists.  ongoing raw eeg data was reviewed at least twice daily by the eeg team
# for detection of seizures and changes in eeg patterns.   all automatically detected events were
# reviewed in detail by the icu monitoring technician or clinical neurophysiology fellow and the
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.
# continuous 1 hz left temporal pleds-plus are captured.  maximal scalp negativity occurs over the
# t3 lead and sharp waves have a broad field.  two typical focal right temporal onset electrographic
# seizures are captured, at 8:44 am (duration 35 sec) and at 8:15 pm (duration 57 sec).  there is no
# various eeg leads demonstrate artifact throughout the recording.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# pleds-plus, continuous, left temporal, 1 hz
# seizure, two, left temporal, 35sec-57 sec
# interpretation:
# this is an abnormal continuous 24-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 1 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and (3) 2
# left temporal subclinical seizures.  there is a focal left hemispheric structural cerebral abnormality,
# especially over the left temporal region, that contains an epileptogenic focus.  diffuse slowing is
# indicative of moderate-to-severe diffuse cerebral dysfunction, which is etiologically nonspecific.
# clear correlate.
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# 100 seconds.  seizure start with low amplitude fast activity over the t3 lead.  1 hz pleds-plus are
# replaced by rhythmic ~1.5 hz left hemispheric delta activity.
# summary of findings:
# diffuse slowing, polymorphic, moderate-to-severe
# seizure, one, left temporal, mid
# pleds-plus, left, 0.75-0.8 hz
# interpretation:
# this is an abnormal continuous ~13-hour eeg due to (1) moderate -to-severe diffuse slowing; (2)
# continuous 0.75- 0.8 hz left temporal periodic lateralized epileptiform discharges (pleds-plus) and
# (3) one left midtemporal focal electrographic seizure.  there is a focal left hemispheric structural
# cerebral abnormality, especially over the left temporal region, that contains an epileptogenic focus.
# diffuse slowing is indicative of moderate-to-severe diffuse cerebral dysfunction, which is
# etiologically nonspecific.  these findings were conveyed to the primary team.
#
#
#
#
#
#
#
# history:	42 year old woman with a history of seizures, now presents in status epilepticus.
# medications:	keppra, vimpat, depakote, ativan
# sedation:
# eeg type:	continuous (inpt, video), 24 hrs
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep
# continuous bedside video-eeg monitoring
# continuous eeg monitoring was performed for ~13 hours from 08/31/2015 till 09/01/2015.
# nursing-initiated event buttons were correlated with clinical behavior.  ongoing raw eeg data was
# reviewed at least twice daily by the eeg team for detection of seizures and changes in eeg
# patterns.   all automatically detected events were reviewed in detail by the attending neurologist.
# # push button events
# description of pushbutton events
# description:
# there is no clear pdr or ap gradient.  during wakefulness, the background consists of polymorphic
# diffuse theta and delta activity activity.  diffuse excess beta activity is present.  sleep spindles and
# k-complexes are captured.  sleep spindles are better formed over the right hemisphere.  patient
# sleeps during majority of the recording.
# continuous moderate amplitude 0.75-0.8 hz left temporal pleds-plus are captured.  maximal
# scalp negativity occurs over the t3 lead and sharp waves have a broad field.  a single
# electrographic seizure is captured at 3:44 am. there is no clinical correlate.  seizure duration is ~
# ...
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
#
#
#
# :
# history:	51 yo female with hx of epilepsy. new breakthrough events w/ loc
# 12/23/2013.
# pt husband has video of event.
# started emu 2/10/14.
# medications:	keppra, ramipril
# sedation:	none
# eeg type:	routine, awake & drowsy
# technique:	international 10-20 system; standard 21 electrodes with t1/t2 electrodes and ekg
# electrodes, awake, drowsy, asleep, hyperventilation, photic
# description:
# waking background is characterized by a 25-40uv, 10hz alpha rhythm, which attenuates
# symmetrically with eye opening.  symmetric 5-15uv, 18-25hz activity is present, maximal over
# bilateral frontal regions.  during drowsiness, the background slows to central theta activity, frontal
# beta activity becomes more prominent, and the alpha rhythm attenuates and becomes intermittent.
# there is continuous focal delta slowing present over the right hemisphere maxima in the fronto-
# temporal region.  there are very frequent right fronto-temporal sharp waves seen maximal at f8-
# hyperventilation is performed for 240 seconds with good cooperation, and produces no effect.
# stepped photic stimulation from 1-21 flashes per second (fps) does not produce any effect.  hr was
# summary of findings:
# sharp waves, frequent, right temporal, anterior
# focal slowing, polymorphic, continuous, right temporal, anterior
# interpretation:
# this is an abnormal eeg, awake, drowsy, and asleep due to focal slowing and spikes in the right
# fronto-temporal region. these findings are indicative of a structural brain lesion and potentially
# epileptogenic focus in this region, and given the clinical history of partial seizures, are consistent
# with a diagnosis of localization-related epilepsy.
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-96-0502329a5651> in <module>
#       2 bpm = []
#       3 for token_fn in all_token_fns:
# ----> 4     txt = read.get_all_clinical_notes(token_fn)
#       5     txt = txt.lower()
#       6     match = re.search(r'(\d+)\s*b\W*p\W*m', txt)
#
# ~/dbmi_eeg_clustering/data_reader.py in get_all_clinical_notes(session_path, edf_convert)
#     259         clinical_notes_path = session_path
#     260     with open(clinical_notes_path, 'r') as f:
# --> 261         lines = f.readlines()
#     262     res = ""
#     263     for line in lines:
#
# ~/miniconda3/envs/keras-redo/lib/python3.7/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc8 in position 1517: invalid continuation byte

# %%
bpm
# Out:
# ['60',
#  '84',
#  '78',
#  '66',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '72',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '88',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '78',
#  '70',
#  '96',
#  '42',
#  '98',
#  '78',
#  '72',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60',
#  '60']

# %%
len(bpm)/len(all_token_fns)
# print(read.get_all_clinical_notes("/home/ms994/v1.5.0/edf/train/01_tcp_ar/103/00010301/s001_2013_05_20/00010301_s001_t000.edf").lower())
# Out:
# 0.02675480012590494
