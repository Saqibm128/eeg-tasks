# %% [markdown]
# # Result Parsing
# Stored results from script into a mongodb instance, gonna try to parse them here

# %%
import sys, os
sys.path.append(os.path.realpath("/home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages"))
import util_funcs
from importlib import reload
reload(util_funcs)
from copy import deepcopy as cp

# %%
successful_run = {"status":"COMPLETED", "experiment.name":"EEG_K-Means_dim_red_Clustering", "num_eegs": None}

# %%
successful_run_pca = cp(successful_run)
successful_run_pca["config.dim_red"] = "pca"
successful_run_ica = cp(successful_run)
successful_run_ica["config.dim_red"] = "ica"

# %%
successful_run_pca
# Out:
# {'status': 'COMPLETED',
#  'experiment.name': 'EEG_K-Means_dim_red_Clustering',
#  'num_eegs': None,
#  'config.dim_red': 'pca',
#  'config.num_comps': 39,
#  'config.num_clusters': 39}

# %%
Dict(exp).cluster_pct
# Out:
# array([[0.04221897, 0.00374526, 0.03277773, ..., 0.00915529, 0.00742351,
#         0.01281336],
#        [0.04420933, 0.00187016, 0.03355145, ..., 0.00758168, 0.00673604,
#         0.01294214],
#        [0.03571992, 0.01270965, 0.02736669, ..., 0.01562827, 0.01339239,
#         0.01593612],
#        ...,
#        [0.04247952, 0.00514567, 0.02853332, ..., 0.00958086, 0.00803708,
#         0.01280381],
#        [0.03988783, 0.00874117, 0.02310925, ..., 0.01221025, 0.0105717 ,
#         0.01397946],
#        [0.03498766, 0.01012349, 0.0257993 , ..., 0.01143173, 0.01119796,
#         0.0136224 ]])

# %%
import numpy as np
import pandas as pd

# %%
num_comps = [i for i in range(1, 40, 2)]
num_clus = [i for i in range(1, 40, 2)]

nmi_scores = pd.DataFrame(index=num_comps, columns=num_clus)

for num_comp in num_comps:
    for num_clu in num_clus:
        successful_run_pca['config.num_comps'] = num_comp
        successful_run_pca['config.num_clusters'] = num_clu
        exp = util_funcs.get_sacred_results(successful_run_pca)
        nmi_scores[num_clu][num_comps] = exp['rand_score']
        
nmi_scores
# Out:
# /home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator PCA from version 0.21.1 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator MiniBatchKMeans from version 0.21.1 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator PCA from version 0.21.1 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
from seaborn import heatmap

# %%
nmi_scores
# Out:
#      1          3            5          7           9          11         13  \
# 1   0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 3   0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 5   0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 7   0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 9   0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 11  0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 13  0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 15  0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 17  0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 19  0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# 21  0.0 -0.0135214 -0.000543658 -0.0151933  0.00205088 -0.0141496 -0.0194673
# ...

# %%
pca = Dict(exp).dim_red
pca.explained_variance_ratio_
fig=plt.figure(figsize=(10, 10), dpi= 300, facecolor='w', edgecolor='k')
plt.bar([i for i in range(10)], pca.explained_variance_ratio_[0:10])
plt.title("PCA Explained Variance")
plt.xlabel("PCA Component")
plt.ylabel("Explained Varianced Ratio")
plt.savefig("pca.png")

# %%
from seaborn import heatmap
import matplotlib.pyplot as plt

# %%
heatmap(data=nmi_scores.astype(float))
plt.title("Rand Score of K-Means of EEG Data")
plt.ylabel("Number of Components")
plt.xlabel("K (Number of Means)")
# Out:
# Text(0.5, 15.0, 'K (Number of Means)')

# %%
nmi_scores.values.dtype
# Out:
# dtype('O')

# %%
import util_funcs
import initial_clustering

# %%
data, annotations = initial_clustering.get_data(None, None, None, "../train_01_tcp_ar_fft.pkl")
import pickle as pkl
rawData = pkl.load(open("../train_01_tcp_ar_fft.pkl", "rb"))

# %%
annotations = pd.DataFrame(annotations, columns = util_funcs.get_annotation_types())

# %%
fig=plt.figure(figsize=(10, 10), dpi= 300, facecolor='w', edgecolor='k')
plt.title("EEG Annotation Frequencies")
plt.bar(util_funcs.get_annotation_types(), annotations.mean())
plt.xticks(rotation='vertical')
plt.ylabel("Frequency")
plt.savefig("EEGAnnFreq.png")

# %%
dfs = [rawDatum[0] for rawDatum in rawData]

# %%
len(rawData)
# Out:
# 2022

# %%
acc = dfs[0]
for i in range(1, len(dfs)):
    acc += dfs[i]
acc /= len(dfs)

# %%
fig=plt.figure(figsize=(10, 10), dpi= 300, facecolor='w', edgecolor='k')
plt.bar((acc.index), acc.sum(axis=1)/ acc.sum().sum())
plt.title("Distribution of Frequencies Over All Channels")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Proportion")
plt.savefig("EEGFreq.png")

# %%
num_comps = [i for i in range(1, 40, 8)]
num_clus = [i for i in range(1, 40, 8)]

nmi_scores = pd.DataFrame(index=num_comps, columns=num_clus)

for num_comp in num_comps:
    for num_clu in num_clus:
        successful_run_ica['config.num_comps'] = num_comp
        successful_run_ica['config.num_clusters'] = num_clu
        exp = util_funcs.get_sacred_results(successful_run_ica)
        nmi_scores[num_clu][num_comps] = exp['rand_score']
        
nmi_scores
# Out:
# /home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator FastICA from version 0.21.1 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator MiniBatchKMeans from version 0.21.1 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /home/saqibm128/miniconda3/envs/keras/lib/python3.7/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator FastICA from version 0.21.1 when using version 0.20.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...

# %%
fig=plt.figure(figsize=(10, 10), dpi= 300, facecolor='w', edgecolor='k')
heatmap(data=nmi_scores.astype(float))
plt.title("Rand Score of K-Means of EEG Data")
plt.ylabel("Number of Components")
plt.xlabel("K (Number of Means)")
plt.savefig("icarand.png")
