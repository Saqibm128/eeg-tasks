# %%
import matplotlib.pyplot as plt
from addict import Dict
import clinical_text_analysis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a2027008c567> in <module>
#       1 import matplotlib.pyplot as plt
#       2 from addict import Dict
# ----> 3 import clinical_text_analysis
#
# ModuleNotFoundError: No module named 'clinical_text_analysis'

# %%
results = Dict(results)

# %%
plt.plot([i*10 for i in range(len(results.history.val_binary_accuracy))],results.history.val_loss)
plt.plot([i*10 for i in range(len(results.history.val_binary_accuracy))],results.history.loss)
plt.legend(["Validation Loss", "Binary Loss"])
plt.xlabel("Num Batches")
# Out:
# Text(0.5, 0, 'Num Batches')

# %%
plt.plot([i*10 for i in range(len(results.history.val_binary_accuracy))], results.history.val_binary_accuracy)
plt.plot([i*10 for i in range(len(results.history.val_binary_accuracy))], results.history.binary_accuracy)
plt.legend(["Validation Acc", "Binary Acc"])
plt.xlabel("Num Batches")
# Out:
# Text(0.5, 0, 'Num Batches')

# %%
import pymongo

# %%
client = pymongo.MongoClient(host="mongodb://34.73.130.41", port=27017)

# %%
client
# Out:
# MongoClient(host=['34.73.130.41:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db.createUser(
  {
    user: "superAdmin",
    pwd: "952S4Z6WIAele59jvClonCJwSYny2rYUjd5mesVQsUyfGi",
    roles: [ { role: "userAdminAnyDatabase", db: "sacred" }, "readWriteAnyDatabase" ]
  }
)
